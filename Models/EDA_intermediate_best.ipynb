# %% [markdown]
# # AutoML Regression Modelling with PyCaret

# %%
import pandas as pd
from pycaret.regression import *
from datetime import datetime, date
# %matplotlib inline

#sen1 = pd.read_csv("sentencing_s.csv")
sen2 = pd.read_csv("./sentencing_post_eda.csv")

# %%
sen2.shape
# Out:
# (1227930, 47)

# %%
sen2[["age", "totpts", "sp_cj_total_days", "totpts_cut_group"]].describe().apply(lambda s: s.apply('{0:.2f}'.format))

# %%
sen2[["age", "totpts", "sp_cj_total_days", "totpts_cut_group"]].hist()

# %%
sen2 = sen2[['sp_cj_total_days', 'gender', 'age', 'race', 'circuit', 'totpts_cut_group', 'clfely']]

data = sen2.sample(frac=0.9, random_state=786)
data_unseen = sen2.drop(data.index)

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (1105137, 7)
# Unseen Data For Predictions: (122793, 7)

# %%
from pycaret.regression import *
X = setup(data = data, target = 'sp_cj_total_days', session_id=123, normalize = True, 
          transformation = True, #transform_target = True
          )

#X = setup(data = data, target = 'sp_cj_total_days', session_id=123, normalize = True, 
#          transformation = True, transform_target = True, 
#          combine_rare_levels = True, rare_level_threshold = 0.05,
#          remove_multicollinearity = True, multicollinearity_threshold = 0.95)

#, categorical_features = ['race', 'gender', 'county', 'judge', 'clfely']           
#['race', 'gender', 'county', 'judge', 'clfely', 'statut', 'offlvl', 'enhanc', 'haboff', 'habvio', 'vcc', 'prrpact', 'prioff', 'lsviol', 'faviol'])
# Out:
# <style  type="text/css" >
# #T_43e74_row27_col1,#T_43e74_row29_col1,#T_43e74_row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_43e74_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_43e74_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_43e74_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_43e74_row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_43e74_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_43e74_row1_col1" class="data row1 col1" >sp_cj_total_days</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_43e74_row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_43e74_row2_col1" class="data row2 col1" >(1105137, 7)</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_43e74_row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_43e74_row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_43e74_row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_43e74_row4_col1" class="data row4 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_43e74_row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_43e74_row5_col1" class="data row5 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_43e74_row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_43e74_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_43e74_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_43e74_row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_43e74_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_43e74_row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_43e74_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_43e74_row9_col1" class="data row9 col1" >(773595, 52)</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_43e74_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_43e74_row10_col1" class="data row10 col1" >(331542, 52)</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_43e74_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_43e74_row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_43e74_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_43e74_row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_43e74_row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_43e74_row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_43e74_row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_43e74_row14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_43e74_row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_43e74_row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_43e74_row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_43e74_row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_43e74_row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_43e74_row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_43e74_row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_43e74_row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_43e74_row19_col0" class="data row19 col0" >USI</td>
#                         <td id="T_43e74_row19_col1" class="data row19 col1" >b6b9</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_43e74_row20_col0" class="data row20 col0" >Imputation Type</td>
#                         <td id="T_43e74_row20_col1" class="data row20 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_43e74_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_43e74_row21_col1" class="data row21 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_43e74_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#                         <td id="T_43e74_row22_col1" class="data row22 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_43e74_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_43e74_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_43e74_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th

# %%
best = compare_models(exclude = ['ransac', 'knn', 'et'])
# Out:
# <style  type="text/css" >
#     #T_70205_ th {
#           text-align: left;
#     }#T_70205_row0_col0,#T_70205_row0_col1,#T_70205_row0_col5,#T_70205_row0_col6,#T_70205_row1_col0,#T_70205_row1_col1,#T_70205_row1_col2,#T_70205_row1_col3,#T_70205_row1_col4,#T_70205_row1_col5,#T_70205_row1_col6,#T_70205_row2_col0,#T_70205_row2_col1,#T_70205_row2_col2,#T_70205_row2_col3,#T_70205_row2_col4,#T_70205_row2_col5,#T_70205_row2_col6,#T_70205_row3_col0,#T_70205_row3_col1,#T_70205_row3_col2,#T_70205_row3_col3,#T_70205_row3_col4,#T_70205_row3_col5,#T_70205_row3_col6,#T_70205_row4_col0,#T_70205_row4_col1,#T_70205_row4_col2,#T_70205_row4_col3,#T_70205_row4_col4,#T_70205_row4_col5,#T_70205_row4_col6,#T_70205_row5_col0,#T_70205_row5_col1,#T_70205_row5_col2,#T_70205_row5_col3,#T_70205_row5_col4,#T_70205_row5_col5,#T_70205_row5_col6,#T_70205_row6_col0,#T_70205_row6_col1,#T_70205_row6_col2,#T_70205_row6_col3,#T_70205_row6_col4,#T_70205_row6_col5,#T_70205_row6_col6,#T_70205_row7_col0,#T_70205_row7_col1,#T_70205_row7_col2,#T_70205_row7_col3,#T_70205_row7_col4,#T_70205_row7_col5,#T_70205_row7_col6,#T_70205_row8_col0,#T_70205_row8_col1,#T_70205_row8_col2,#T_70205_row8_col3,#T_70205_row8_col4,#T_70205_row8_col5,#T_70205_row8_col6,#T_70205_row9_col0,#T_70205_row9_col2,#T_70205_row9_col3,#T_70205_row9_col4,#T_70205_row10_col0,#T_70205_row10_col1,#T_70205_row10_col2,#T_70205_row10_col3,#T_70205_row10_col4,#T_70205_row10_col5,#T_70205_row10_col6,#T_70205_row11_col0,#T_70205_row11_col1,#T_70205_row11_col2,#T_70205_row11_col3,#T_70205_row11_col4,#T_70205_row11_col5,#T_70205_row11_col6,#T_70205_row12_col0,#T_70205_row12_col1,#T_70205_row12_col2,#T_70205_row12_col3,#T_70205_row12_col4,#T_70205_row12_col5,#T_70205_row12_col6,#T_70205_row13_col0,#T_70205_row13_col1,#T_70205_row13_col2,#T_70205_row13_col3,#T_70205_row13_col4,#T_70205_row13_col5,#T_70205_row13_col6,#T_70205_row14_col0,#T_70205_row14_col1,#T_70205_row14_col2,#T_70205_row14_col3,#T_70205_row14_col4,#T_70205_row14_col5,#T_70205_row14_col6,#T_70205_row15_col0,#T_70205_row15_col1,#T_70205_row15_col2,#T_70205_row15_col3,#T_70205_row15_col4,#T_70205_row15_col5,#T_70205_row15_col6,#T_70205_row16_col0,#T_70205_row16_col1,#T_70205_row16_col2,#T_70205_row16_col3,#T_70205_row16_col4,#T_70205_row16_col5,#T_70205_row16_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_70205_row0_col2,#T_70205_row0_col3,#T_70205_row0_col4,#T_70205_row9_col1,#T_70205_row9_col5,#T_70205_row9_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_70205_row0_col7,#T_70205_row1_col7,#T_70205_row2_col7,#T_70205_row3_col7,#T_70205_row4_col7,#T_70205_row5_col7,#T_70205_row6_col7,#T_70205_row7_col7,#T_70205_row8_col7,#T_70205_row9_col7,#T_70205_row10_col7,#T_70205_row11_col7,#T_70205_row12_col7,#T_70205_row13_col7,#T_70205_row14_col7,#T_70205_row16_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_70205_row15_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_70205_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_70205_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#                         <td id="T_70205_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_70205_row0_col1" class="data row0 col1" >253.2113</td>
#                         <td id="T_70205_row0_col2" class="data row0 col2" >311939.2296</td>
#                         <td id="T_70205_row0_col3" class="data row0 col3" >558.4829</td>
#                         <td id="T_70205_row0_col4" class="data row0 col4" >0.5428</td>
#                         <td id="T_70205_row0_col5" class="data row0 col5" >3.0685</td>
#                         <td id="T_70205_row0_col6" class="data row0 col6" >2.8403</td>
#                         <td id="T_70205_row0_col7" class="data row0 col7" >2.2390</td>
#             </tr>
#             <tr>
#                         <th id="T_70205_level0_row1" class="row_heading level0 row1" >xgboost</th>
#                         <td id="T_70205_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_70205_row1_col1" class="data row1 col1" >252.3577</td>
#                         <td id="T_70205_row1_col2" class="data row1 col2" >313228.6516</td>
#                         <td id="T_70205_row1_col3" class="data row1 col3" >559.6328</td>
#                         <td id="T_70205_row1_col4" class="data row1 col4" >0.5410</td>
#                         <td id="T_70205_row1_col5" class="data row1 col5" >3.0421</td>
#                         <td id="T_70205_row1_col6" class="data row1 col6" >2.8306</td>
#                         <td id="T_70205_row1_col7" class="data row1 col7" >42.1340</td>
#             </tr>
#             <tr>
#                         <th id="T_70205_level0_row2" class="row_heading level0 row2" >gbr</th>
#                         <td id="T_70205_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#                         <td id="T_70205_row2_col1" class="data row2 col1" >264.6182</td>
#                         <td id="T_70205_row2_col2" class="data row2 col2" >329299.0261</td>
#                         <td id="T_70205_row2_col3" class="data row2 col3" >573.8105</td>
#                         <td id="T_70205_row2_col4" class="data row2 col4" >0.5174</td>
#                         <td id="T_70205_row2_col5" class="data row2 col5" >3.1673</td>
#                         <td id="T_70205_row2_col6" class="data row2 col6" >3.1292</td>
#                         <td id="T_70205_row2_col7" class="data row2 col7" >59.2490</td>
#             </tr>
#             <tr>
#                         <th id="T_70205_level0_row3" class="row_heading level0 row3" >ridge</th>
#                         <td id="T_70205_row3_col0" class="data row3 col0" >Ridge Regression</td>
#                         <td id="T_70205_row3_col1" class="data row3 col1" >266.3206</td>
#                         <td id="T_70205_row3_col2" class="data row3 col2" >335005.2701</td>
#                         <td id="T_70205_row3_col3" class="data row3 col3" >578.7639</td>
#                         <td id="T_70205_row3_col4" class="data row3 col4" >0.5091</td>
#                         <td id="T_70205_row3_col5" class="data row3 col5" >3.1473</td>
#                         <td id="T_70205_row3_col6" class="data row3 col6" >3.1231</td>
#                         <td id="T_70205_row3_col7" class="data row3 col7" >0.2570</td>
#             </tr>
#             <tr>
#                         <th id="T_70205_level0_row4" class="row_heading level0 row4" >lar</th>
#                         <td id="T_70205_row4_col0" class="data row4 col0" >Least Angle Regression</td>
#                         <td id="T_70205_row4_col1" class="data row4 col1" >266.3187</td>
#                         <td id="T_70205_row4_col2" class="data row4 col2" >335005.4045</td>
#                         <td id="T_70205_row4_col3" class="data row4 col3" >578.7640</td>
#                         <td id="T_70205_row4_col4" class="data row4 col4" >0.5091</td>
#                         <td id="T_70205_row4_col5" class="data row4 col5" >3.1473</td>
#                         <td id="T_70205_row4_col6" class="data row4 col6" >3.1230</td>
#                         <td id="T_70205_row4_col7" class="data row4 col7" >0.2670</td>
#             </tr>

# %%
lightgbm = create_model('lightgbm')
# Out:
# <style  type="text/css" >
# #T_e6e96_row10_col0,#T_e6e96_row10_col1,#T_e6e96_row10_col2,#T_e6e96_row10_col3,#T_e6e96_row10_col4,#T_e6e96_row10_col5{
#             background:  yellow;
#         }</style><table id="T_e6e96_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e6e96_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e6e96_row0_col0" class="data row0 col0" >253.7728</td>
#                         <td id="T_e6e96_row0_col1" class="data row0 col1" >310888.3147</td>
#                         <td id="T_e6e96_row0_col2" class="data row0 col2" >557.5736</td>
#                         <td id="T_e6e96_row0_col3" class="data row0 col3" >0.5438</td>
#                         <td id="T_e6e96_row0_col4" class="data row0 col4" >3.0690</td>
#                         <td id="T_e6e96_row0_col5" class="data row0 col5" >2.9236</td>
#             </tr>
#             <tr>
#                         <th id="T_e6e96_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e6e96_row1_col0" class="data row1 col0" >252.3778</td>
#                         <td id="T_e6e96_row1_col1" class="data row1 col1" >302393.1856</td>
#                         <td id="T_e6e96_row1_col2" class="data row1 col2" >549.9029</td>
#                         <td id="T_e6e96_row1_col3" class="data row1 col3" >0.5512</td>
#                         <td id="T_e6e96_row1_col4" class="data row1 col4" >3.0622</td>
#                         <td id="T_e6e96_row1_col5" class="data row1 col5" >2.7583</td>
#             </tr>
#             <tr>
#                         <th id="T_e6e96_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e6e96_row2_col0" class="data row2 col0" >254.4274</td>
#                         <td id="T_e6e96_row2_col1" class="data row2 col1" >322334.0560</td>
#                         <td id="T_e6e96_row2_col2" class="data row2 col2" >567.7447</td>
#                         <td id="T_e6e96_row2_col3" class="data row2 col3" >0.5364</td>
#                         <td id="T_e6e96_row2_col4" class="data row2 col4" >3.0794</td>
#                         <td id="T_e6e96_row2_col5" class="data row2 col5" >2.9235</td>
#             </tr>
#             <tr>
#                         <th id="T_e6e96_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e6e96_row3_col0" class="data row3 col0" >252.4603</td>
#                         <td id="T_e6e96_row3_col1" class="data row3 col1" >310654.2016</td>
#                         <td id="T_e6e96_row3_col2" class="data row3 col2" >557.3636</td>
#                         <td id="T_e6e96_row3_col3" class="data row3 col3" >0.5483</td>
#                         <td id="T_e6e96_row3_col4" class="data row3 col4" >3.0673</td>
#                         <td id="T_e6e96_row3_col5" class="data row3 col5" >2.8366</td>
#             </tr>
#             <tr>
#                         <th id="T_e6e96_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e6e96_row4_col0" class="data row4 col0" >257.0202</td>
#                         <td id="T_e6e96_row4_col1" class="data row4 col1" >324846.3002</td>
#                         <td id="T_e6e96_row4_col2" class="data row4 col2" >569.9529</td>
#                         <td id="T_e6e96_row4_col3" class="data row4 col3" >0.5339</td>
#                         <td id="T_e6e96_row4_col4" class="data row4 col4" >3.0746</td>
#                         <td id="T_e6e96_row4_col5" class="data row4 col5" >2.8310</td>
#             </tr>
#             <tr>
#                         <th id="T_e6e96_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e6e96_row5_col0" class="data row5 col0" >251.8290</td>
#                         <td id="T_e6e96_row5_col1" class="data row5 col1" >308949.9301</td>
#                         <td id="T_e6e96_row5_col2" class="data row5 col2" >555.8326</td>
#                         <td id="T_e6e96_row5_col3" class="data row5 col3" >0.5431</td>
#                         <td id="T_e6e96_row5_col4" class="data row5 col4" >3.0665</td>
#                         <td id="T_e6e96_row5_col5" class="data row5 col5" >2.9053</td>
#             </tr>
#             <tr>
#                         <th id="T_e6e96_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_e6e96_row6_col0" class="data row6 col0" >253.3701</td>
#                         <td id="T_e6e96_row6_col1" class="data row6 col1" >312374.9677</td>
#                         <td id="T_e6e96_row6_col2" class="data row6 col2" >558.9052</td>
#                         <td id="T_e6e96_row6_col3" class="data row6 col3" >0.5313</td>
#                         <td id="T_e6e96_row6_col4" class="data row6 col4" >3.0625</td>
#                         <td id="T_e6e96_row6_col5" class="data row6 col5" >2.8030</td>
#             </tr>
#             <tr>
#                         <th id="T_e6e96_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_e6e96_row7_col0" class="data row7 col0" >252.0076</td>
#                         <td id="T_e6e96_row7_col1" class="data row7 col1" >303805.3952</td>
#                         <td id="T_e6e96_row7_col2" class="data row7 col2" >551.1854</td>
#                         <td id="T_e6e96_row7_col3" class="data row7 col3" >0.5375</td>
#                         <td id="T_e6e96_row7_col4" class="data row7 col4" >3.0730</td>
#                         <td id="T_e6e96_row7_col5" class="data row7 col5" >2.8654</td>
#             </tr>
#             <tr>
#                         <th id="T_e6e96_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_e6e96_row8_col0" class="data row8 col0" >251.9550</td>
#                         <td id="T_e6e96_row8_col1" class="data row8 col1" >309491.7787</td>
#                         <td id="T_e6e96_row8_col2" class="data row8 col2" >556.3199</td>
#                         <td id="T_e6e96_row8_col3" class="data row8 col3" >0.5499</td>
#                         <td id="T_e6e96_row8_col4" class="data row8 col4" >3.0671</td>
#                         <td id="T_e6e96_row8_col5" class="data row8 col5" >2.8682</td>
#             </tr>
#             <tr>
#                         <th id="T_e6e96_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_e6e96_row9_col0" class="data row9 col0" >252.8933</td>
#                         <td id="T_e6e96_row9_col1" class="data row9 col1" >313654.1664</td>
#                         <td id="T_e6e96_row9_col2" class="data row9 col2" >560.0484</td>
#                         <td id="T_e6e96_row9_col3" class="data row9 col3" >0.5529</td>
#                         <td id="T_e6e96_row9_col4" class="data row9 col4" >3.0636</td>
#                         <td id="T_e6e96_row9_col5" class="data row9 col5" >2.6886</td>
#             </tr>
#             <tr>
#                         <th id="T_e6e96_level0_row10" class="row_heading level0 row10" >Mean</th>
#                         <td id="T_e6e96_row10_col0" class="data row10 col0" >253.2113</td>
#                         <td id="T_e6e96_row10_col1" class="data row10 col1" >311939.2296</td>
#                         <td id="T_e6e96_row10_col2" class="data row10 col2" >558.4829</td>
#                         <td id="T_e6e96_row10_col3" class="data row10 col3" >0.5428</td>
#                         <td id="T_e6e96_row10_col4" class="data row10 col4" >3.0685</td>
#                         <td id="T_e6e96_row10_col5" class="data row10 col5" >2.8403</td>
#             </tr>
#             <tr>
#                         <th id="T_e6e96_level0_row11" class="row_heading level0 row11" >SD</th

# %%
import numpy as np
lgbm_params = {'num_leaves': np.arange(10,200,10),
                        'max_depth': [int(x) for x in np.linspace(10, 110, num = 11)],
                        'learning_rate': np.arange(0.1,1,0.1)
                        }
tuned_lightgbm = tune_model(lightgbm, custom_grid = lgbm_params)
# Out:
# <style  type="text/css" >
# #T_80418_row10_col0,#T_80418_row10_col1,#T_80418_row10_col2,#T_80418_row10_col3,#T_80418_row10_col4,#T_80418_row10_col5{
#             background:  yellow;
#         }</style><table id="T_80418_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_80418_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_80418_row0_col0" class="data row0 col0" >253.1874</td>
#                         <td id="T_80418_row0_col1" class="data row0 col1" >311271.6354</td>
#                         <td id="T_80418_row0_col2" class="data row0 col2" >557.9172</td>
#                         <td id="T_80418_row0_col3" class="data row0 col3" >0.5433</td>
#                         <td id="T_80418_row0_col4" class="data row0 col4" >3.0683</td>
#                         <td id="T_80418_row0_col5" class="data row0 col5" >2.9201</td>
#             </tr>
#             <tr>
#                         <th id="T_80418_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_80418_row1_col0" class="data row1 col0" >251.1928</td>
#                         <td id="T_80418_row1_col1" class="data row1 col1" >301415.3814</td>
#                         <td id="T_80418_row1_col2" class="data row1 col2" >549.0131</td>
#                         <td id="T_80418_row1_col3" class="data row1 col3" >0.5526</td>
#                         <td id="T_80418_row1_col4" class="data row1 col4" >3.0654</td>
#                         <td id="T_80418_row1_col5" class="data row1 col5" >2.7420</td>
#             </tr>
#             <tr>
#                         <th id="T_80418_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_80418_row2_col0" class="data row2 col0" >253.6843</td>
#                         <td id="T_80418_row2_col1" class="data row2 col1" >321317.5053</td>
#                         <td id="T_80418_row2_col2" class="data row2 col2" >566.8487</td>
#                         <td id="T_80418_row2_col3" class="data row2 col3" >0.5379</td>
#                         <td id="T_80418_row2_col4" class="data row2 col4" >3.0755</td>
#                         <td id="T_80418_row2_col5" class="data row2 col5" >2.9140</td>
#             </tr>
#             <tr>
#                         <th id="T_80418_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_80418_row3_col0" class="data row3 col0" >251.9372</td>
#                         <td id="T_80418_row3_col1" class="data row3 col1" >311606.4008</td>
#                         <td id="T_80418_row3_col2" class="data row3 col2" >558.2172</td>
#                         <td id="T_80418_row3_col3" class="data row3 col3" >0.5469</td>
#                         <td id="T_80418_row3_col4" class="data row3 col4" >3.0672</td>
#                         <td id="T_80418_row3_col5" class="data row3 col5" >2.8410</td>
#             </tr>
#             <tr>
#                         <th id="T_80418_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_80418_row4_col0" class="data row4 col0" >256.4175</td>
#                         <td id="T_80418_row4_col1" class="data row4 col1" >325563.8801</td>
#                         <td id="T_80418_row4_col2" class="data row4 col2" >570.5821</td>
#                         <td id="T_80418_row4_col3" class="data row4 col3" >0.5328</td>
#                         <td id="T_80418_row4_col4" class="data row4 col4" >3.0753</td>
#                         <td id="T_80418_row4_col5" class="data row4 col5" >2.8295</td>
#             </tr>
#             <tr>
#                         <th id="T_80418_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_80418_row5_col0" class="data row5 col0" >250.6418</td>
#                         <td id="T_80418_row5_col1" class="data row5 col1" >309037.8733</td>
#                         <td id="T_80418_row5_col2" class="data row5 col2" >555.9117</td>
#                         <td id="T_80418_row5_col3" class="data row5 col3" >0.5430</td>
#                         <td id="T_80418_row5_col4" class="data row5 col4" >3.0668</td>
#                         <td id="T_80418_row5_col5" class="data row5 col5" >2.9034</td>
#             </tr>
#             <tr>
#                         <th id="T_80418_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_80418_row6_col0" class="data row6 col0" >253.1617</td>
#                         <td id="T_80418_row6_col1" class="data row6 col1" >314265.7781</td>
#                         <td id="T_80418_row6_col2" class="data row6 col2" >560.5941</td>
#                         <td id="T_80418_row6_col3" class="data row6 col3" >0.5285</td>
#                         <td id="T_80418_row6_col4" class="data row6 col4" >3.0594</td>
#                         <td id="T_80418_row6_col5" class="data row6 col5" >2.8031</td>
#             </tr>
#             <tr>
#                         <th id="T_80418_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_80418_row7_col0" class="data row7 col0" >250.8528</td>
#                         <td id="T_80418_row7_col1" class="data row7 col1" >303390.8427</td>
#                         <td id="T_80418_row7_col2" class="data row7 col2" >550.8093</td>
#                         <td id="T_80418_row7_col3" class="data row7 col3" >0.5381</td>
#                         <td id="T_80418_row7_col4" class="data row7 col4" >3.0665</td>
#                         <td id="T_80418_row7_col5" class="data row7 col5" >2.8489</td>
#             </tr>
#             <tr>
#                         <th id="T_80418_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_80418_row8_col0" class="data row8 col0" >251.2742</td>
#                         <td id="T_80418_row8_col1" class="data row8 col1" >310210.4907</td>
#                         <td id="T_80418_row8_col2" class="data row8 col2" >556.9654</td>
#                         <td id="T_80418_row8_col3" class="data row8 col3" >0.5489</td>
#                         <td id="T_80418_row8_col4" class="data row8 col4" >3.0645</td>
#                         <td id="T_80418_row8_col5" class="data row8 col5" >2.8641</td>
#             </tr>
#             <tr>
#                         <th id="T_80418_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_80418_row9_col0" class="data row9 col0" >252.0060</td>
#                         <td id="T_80418_row9_col1" class="data row9 col1" >313151.5976</td>
#                         <td id="T_80418_row9_col2" class="data row9 col2" >559.5995</td>
#                         <td id="T_80418_row9_col3" class="data row9 col3" >0.5536</td>
#                         <td id="T_80418_row9_col4" class="data row9 col4" >3.0601</td>
#                         <td id="T_80418_row9_col5" class="data row9 col5" >2.6933</td>
#             </tr>
#             <tr>
#                         <th id="T_80418_level0_row10" class="row_heading level0 row10" >Mean</th>
#                         <td id="T_80418_row10_col0" class="data row10 col0" >252.4356</td>
#                         <td id="T_80418_row10_col1" class="data row10 col1" >312123.1385</td>
#                         <td id="T_80418_row10_col2" class="data row10 col2" >558.6458</td>
#                         <td id="T_80418_row10_col3" class="data row10 col3" >0.5426</td>
#                         <td id="T_80418_row10_col4" class="data row10 col4" >3.0669</td>
#                         <td id="T_80418_row10_col5" class="data row10 col5" >2.8359</td>
#             </tr>
#             <tr>
#                         <th id="T_80418_level0_row11" class="row_heading level0 row11" >SD</th

# %%
print(tuned_lightgbm)
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.1, max_depth=60,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=100, n_jobs=-1, num_leaves=120, objective=None,
#               random_state=123, reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
plot_model(tuned_lightgbm)

# %%
plot_model(tuned_lightgbm, plot = 'error')

# %%
plot_model(tuned_lightgbm, plot='feature')

# %%
predict_model(tuned_lightgbm);
# Out:
# <style  type="text/css" >
# </style><table id="T_243ba_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_243ba_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_243ba_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_243ba_row0_col1" class="data row0 col1" >252.3496</td>
#                         <td id="T_243ba_row0_col2" class="data row0 col2" >313264.5550</td>
#                         <td id="T_243ba_row0_col3" class="data row0 col3" >559.7004</td>
#                         <td id="T_243ba_row0_col4" class="data row0 col4" >0.5436</td>
#                         <td id="T_243ba_row0_col5" class="data row0 col5" >3.0641</td>
#                         <td id="T_243ba_row0_col6" class="data row0 col6" >2.8826</td>
#             </tr>
#     </tbody></table>

# %%
final_lightgbm = finalize_model(tuned_lightgbm)

# %%
print(final_lightgbm)
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.1, max_depth=60,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=100, n_jobs=-1, num_leaves=120, objective=None,
#               random_state=123, reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
predict_model(final_lightgbm);
# Out:
# <style  type="text/css" >
# </style><table id="T_0a48d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0a48d_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0a48d_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_0a48d_row0_col1" class="data row0 col1" >248.7339</td>
#                         <td id="T_0a48d_row0_col2" class="data row0 col2" >294096.5952</td>
#                         <td id="T_0a48d_row0_col3" class="data row0 col3" >542.3067</td>
#                         <td id="T_0a48d_row0_col4" class="data row0 col4" >0.5715</td>
#                         <td id="T_0a48d_row0_col5" class="data row0 col5" >3.0635</td>
#                         <td id="T_0a48d_row0_col6" class="data row0 col6" >2.8791</td>
#             </tr>
#     </tbody></table>

# %%
unseen_predictions = predict_model(final_lightgbm, data=data_unseen)
unseen_predictions.head(25)
# Out:
#     sp_cj_total_days  gender  age   race                       circuit  \
# 0               3902    MALE   39  BLACK            CIRCUIT 11 - MIAMI
# 1               3259    MALE   25  BLACK   CIRCUIT 17 - FT. LAUDERDALE
# 2               5840    MALE   27  WHITE            CIRCUIT 11 - MIAMI
# 3                660    MALE   31  BLACK            CIRCUIT 11 - MIAMI
# 4               1176    MALE   44  BLACK     CIRCUIT 04 - JACKSONVILLE
# 5                900    MALE   41  WHITE       CIRCUIT 06 - CLEARWATER
# 6               2920    MALE   52  WHITE            CIRCUIT 11 - MIAMI
# 7               1560    MALE   49  BLACK         CIRCUIT 20 - FT MYERS
# 8                774    MALE   31  BLACK            CIRCUIT 11 - MIAMI
# 9               2938    MALE   45  WHITE            CIRCUIT 11 - MIAMI
# 10               180    MALE   30  BLACK          CIRCUIT 09 - ORLANDO
# 11               936    MALE   47  BLACK            CIRCUIT 13 - TAMPA
# 12              1825    MALE   34  WHITE          CIRCUIT 05 - TAVARES
# 13               456    MALE   38  WHITE       CIRCUIT 06 - CLEARWATER
# 14               607    MALE   30  WHITE       CIRCUIT 06 - CLEARWATER
# 15               180  FEMALE   21  WHITE  CIRCUIT 15 - WEST PALM BEACH
# 16               522    MALE   38  BLACK   CIRCUIT 17 - FT. LAUDERDALE
# 17               545    MALE   32  WHITE            CIRCUIT 11 - MIAMI
# 18              3650    MALE   47  BLACK       CIRCUIT 19 - FT. PIERCE
# 19              2245    MALE   56  WHITE   CIRCUIT 17 - FT. LAUDERDALE
# 20                30    MALE   36  WHITE            CIRCUIT 11 - MIAMI
# 21              1825    MALE   57  BLACK            CIRCUIT 11 - MIAMI
# 22              1107    MALE   45  WHITE       CIRCUIT 06 - CLEARWATER
# 23               765    MALE   35  BLACK   CIRCUIT 17 - FT. LAUDERDALE
# 24               720    MALE   20  BLACK         CIRCUIT 12 - SARASOTA
#
#     totpts_cut_group      clfely        Label
# 0                 17  1ST DEGREE  2312.340193
# 1                 14    1ST/LIFE  3826.390273
# 2                  8  2ND DEGREE  1331.965303
# 3                  4  2ND DEGREE   652.616726
# 4                  3  3RD DEGREE   791.942531
# 5                  8  2ND DEGREE  2474.862670
# 6                 12  2ND DEGREE  1712.975194
# 7                  7  1ST DEGREE  2034.031709
# 8                  3  2ND DEGREE   579.078693
# 9                 13    1ST/LIFE  2392.944393
# 10                10  1ST DEGREE  2599.492461
# 11                 4  2ND DEGREE   992.832661
# 12                 7  2ND DEGREE  2040.906712
# 13                 2  2ND DEGREE   563.037639
# 14                 3  3RD DEGREE   714.310556
# 15                 1  2ND DEGREE    86.884840
# 16                 2  3RD DEGREE   563.271276
# 17                 8  3RD DEGREE   773.813518
# 18                12  1ST DEGREE  4544.224311
# 19                10  3RD DEGREE  1420.532632
# 20                 2  3RD DEGREE   375.090790
# 21                10  1ST DEGREE  1294.895784
# 22                 5  3RD DEGREE  1033.102017
# 23                 3  3RD DEGREE   768.809813
# 24                 3  3RD DEGREE   769.009814

# %%
from pycaret.utils import check_metric
check_metric(unseen_predictions.sp_cj_total_days, unseen_predictions.Label, 'R2')
# Out:
# 0.545

# %%
check_metric(unseen_predictions[unseen_predictions.race=="BLACK"].sp_cj_total_days, unseen_predictions[unseen_predictions.race=="BLACK"].Label, 'R2')
# Out:
# 0.4931

# %%
check_metric(unseen_predictions[unseen_predictions.race=="WHITE"].sp_cj_total_days, unseen_predictions[unseen_predictions.race=="WHITE"].Label, 'R2')
# Out:
# 0.5242

# %%
save_model(final_lightgbm,'Final LightGBM Model Int 23Feb2022')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[],
#                                        target='sp_cj_total_days',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric...
#                   LGBMRegressor(boosting_type='gbdt', class_weight=None,
#                                 colsample_bytree=1.0, importance_type='split',
#                                 learning_rate=0.1, max_depth=60,
#                                 min_child_samples=20, min_child_weight=0.001,
#                                 min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                 num_leaves=120, objective=None, random_state=123,
#                                 reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#                                 subsample=1.0, subsample_for_bin=200000,
#                                 subsample_freq=0)]],
#           verbose=False),
#  'Final LightGBM Model Int 23Feb2022.pkl')

# %%
get_config('X_train').shape
# Out:
# (773595, 52)

# %%
unseen_predictions.head(50)
# Out:
#     sp_cj_total_days  gender  age   race                       circuit  \
# 0               3902    MALE   39  BLACK            CIRCUIT 11 - MIAMI
# 1               3259    MALE   25  BLACK   CIRCUIT 17 - FT. LAUDERDALE
# 2               5840    MALE   27  WHITE            CIRCUIT 11 - MIAMI
# 3                660    MALE   31  BLACK            CIRCUIT 11 - MIAMI
# 4               1176    MALE   44  BLACK     CIRCUIT 04 - JACKSONVILLE
# 5                900    MALE   41  WHITE       CIRCUIT 06 - CLEARWATER
# 6               2920    MALE   52  WHITE            CIRCUIT 11 - MIAMI
# 7               1560    MALE   49  BLACK         CIRCUIT 20 - FT MYERS
# 8                774    MALE   31  BLACK            CIRCUIT 11 - MIAMI
# 9               2938    MALE   45  WHITE            CIRCUIT 11 - MIAMI
# 10               180    MALE   30  BLACK          CIRCUIT 09 - ORLANDO
# 11               936    MALE   47  BLACK            CIRCUIT 13 - TAMPA
# 12              1825    MALE   34  WHITE          CIRCUIT 05 - TAVARES
# 13               456    MALE   38  WHITE       CIRCUIT 06 - CLEARWATER
# 14               607    MALE   30  WHITE       CIRCUIT 06 - CLEARWATER
# 15               180  FEMALE   21  WHITE  CIRCUIT 15 - WEST PALM BEACH
# 16               522    MALE   38  BLACK   CIRCUIT 17 - FT. LAUDERDALE
# 17               545    MALE   32  WHITE            CIRCUIT 11 - MIAMI
# 18              3650    MALE   47  BLACK       CIRCUIT 19 - FT. PIERCE
# 19              2245    MALE   56  WHITE   CIRCUIT 17 - FT. LAUDERDALE
# 20                30    MALE   36  WHITE            CIRCUIT 11 - MIAMI
# 21              1825    MALE   57  BLACK            CIRCUIT 11 - MIAMI
# 22              1107    MALE   45  WHITE       CIRCUIT 06 - CLEARWATER
# 23               765    MALE   35  BLACK   CIRCUIT 17 - FT. LAUDERDALE
# 24               720    MALE   20  BLACK         CIRCUIT 12 - SARASOTA
# 25              1825    MALE   21  BLACK            CIRCUIT 11 - MIAMI
# 26               366    MALE   24  BLACK            CIRCUIT 11 - MIAMI
# 27              1095    MALE   19  WHITE          CIRCUIT 05 - TAVARES
# 28              1440    MALE   32  BLACK            CIRCUIT 13 - TAMPA
# 29               909    MALE   25  BLACK    CIRCUIT 07 - DAYTONA BEACH
# 30               540    MALE   18  BLACK           CIRCUIT 10 - BARTOW
# 31              2355    MALE   43  BLACK            CIRCUIT 13 - TAMPA
# 32               420    MALE   19  BLACK     CIRCUIT 04 - JACKSONVILLE
# 33                 0    MALE   35  BLACK            CIRCUIT 11 - MIAMI
# 34                24    MALE   48  BLACK  CIRCUIT 15 - WEST PALM BEACH
# 35               840    MALE   32  BLACK   CIRCUIT 17 - FT. LAUDERDALE
# 36                 0    MALE   29  WHITE       CIRCUIT 06 - CLEARWATER
# 37               757    MALE   19  BLACK     CIRCUIT 04 - JACKSONVILLE
# 38                 0  FEMALE   24  BLACK          CIRCUIT 09 - ORLANDO
# 39              1460    MALE   48  WHITE       CIRCUIT 06 - CLEARWATER
# 40              1440    MALE   32  WHITE        CIRCUIT 01 - PENSACOLA
# 41              1327    MALE   27  WHITE            CIRCUIT 13 - TAMPA
# 42                30    MALE   33  BLACK     CIRCUIT 04 - JACKSONVILLE
# 43              2103    MALE   18  BLACK          CIRCUIT 05 - TAVARES
# 44               810    MALE   21  BLACK          CIRCUIT 09 - ORLANDO
# 45              1151    MALE   50  WHITE   CIRCUIT 17 - FT. LAUDERDALE
# 46               364    MALE   34  BLACK            CIRCUIT 11 - MIAMI
# 47                 0    MALE   46  WHITE    CIRCUIT 07 - DAYTONA BEACH
# 48              1275    MALE   23  BLACK            CIRCUIT 13 - TAMPA
# 49               336    MALE   43  WHITE  CIRCUIT 15 - WEST PALM BEACH
#
#     totpts_cut_group      clfely        Label
# 0                 17  1ST DEGREE  2555.363645
# 1                 14    1ST/LIFE  3945.286783
# 2                  8  2ND DEGREE  1301.035361
# 3                  4  2ND DEGREE   670.433049
# 4                  3  3RD DEGREE   790.995362
# 5                  8  2ND DEGREE  2556.103614
# 6                 12  2ND DEGREE  1774.059328
# 7                  7  1ST DEGREE  2035.329667
# 8                  3  2ND DEGREE   584.420510
# 9                 13    1ST/LIFE  2464.809742
# 10                10  1ST DEGREE  2500.739250
# 11                 4  2ND DEGREE  1009.066311
# 12                 7  2ND DEGREE  1999.257593
# 13                 2  2ND DEGREE   564.549528
# 14                 3  3RD DEGREE   718.973808
# 15                 1  2ND DEGREE    85.461552
# 16                 2  3RD DEGREE   572.175049
# 17                 8  3RD DEGREE   776.345096
# 18                12  1ST DEGREE  4677.369707
# 19                10  3RD DEGREE  1478.436488
# 20                 2  3RD DEGREE   372.430754
# 21                10  1ST DEGREE  1354.608057
# 22                 5  3RD DEGREE  1032.009983
# 23                 3  3RD DEGREE   787.837021
# 24                 3  3RD DEGREE   741.842153
# 25                 6  2ND DEGREE   934.443785
# 26                 3  3RD DEGREE   418.663668
# 27                 7  2ND DEGREE  1270.849887
# 28                 7  2ND DEGREE  1557.686794
# 29                 4  3RD DEGREE   916.279938
# 30                 9  2ND DEGREE  1530.217108
# 31                10  2ND DEGREE  2056.100908
# 32                 2  2ND DEGREE  1027.741904
# 33                 1  3RD DEGREE    61.152856
# 34                 5  3RD DEGREE   934.774542
# 35                 3  3RD DEGREE   787.837021
# 36                 0  3RD DEGREE    50.866482
# 37                 2  2ND DEGREE  1027.741904
# 38                 1  3RD DEGREE   138.506028
# 39                10  3RD DEGREE  1427.578683
# 40                 6  3RD DEGREE  1325.065910
# 41                 6  3RD DEGREE  1014.536355
# 42                 1  3RD DEGREE   332.416965
# 43                 9  2ND DEGREE  1666.219717
# 44                 3  3RD DEGREE   646.437465
# 45                 2  3RD DEGREE   565.416734
# 46                 1  3RD DEGREE    61.152856
# 47                 1  3RD DEGREE   179.654630
# 48                 6  2ND DEGREE  1511.683951
# 49                 5  3RD DEGREE   993.652104

# %%
get_config('X_train').dtypes
# Out:
# age                                     float32
# gender_FEMALE                           float32
# race_BLACK                              float32
# race_OTHER                              float32
# race_WHITE                              float32
# circuit_0                               float32
# circuit_97                              float32
# circuit_CIRCUIT 01 - PENSACOLA          float32
# circuit_CIRCUIT 02 - TALLAHASSEE        float32
# circuit_CIRCUIT 03 - LAKE CITY          float32
# circuit_CIRCUIT 04 - JACKSONVILLE       float32
# circuit_CIRCUIT 05 - TAVARES            float32
# circuit_CIRCUIT 06 - CLEARWATER         float32
# circuit_CIRCUIT 07 - DAYTONA BEACH      float32
# circuit_CIRCUIT 08 - GAINESVILLE        float32
# circuit_CIRCUIT 09 - ORLANDO            float32
# circuit_CIRCUIT 10 - BARTOW             float32
# circuit_CIRCUIT 11 - MIAMI              float32
# circuit_CIRCUIT 12 - SARASOTA           float32
# circuit_CIRCUIT 13 - TAMPA              float32
# circuit_CIRCUIT 14 - PANAMA CITY        float32
# circuit_CIRCUIT 15 - WEST PALM BEACH    float32
# circuit_CIRCUIT 16 - KEY WEST           float32
# circuit_CIRCUIT 17 - FT. LAUDERDALE     float32
# circuit_CIRCUIT 18 - SANFORD            float32
# circuit_CIRCUIT 19 - FT. PIERCE         float32
# circuit_CIRCUIT 20 - FT MYERS           float32
# circuit_MISSING                         float32
# totpts_cut_group_0                      float32
# totpts_cut_group_1                      float32
# totpts_cut_group_10                     float32
# totpts_cut_group_11                     float32
# totpts_cut_group_12                     float32
# totpts_cut_group_13                     float32
# totpts_cut_group_14                     float32
# totpts_cut_group_15                     float32
# totpts_cut_group_16                     float32
# totpts_cut_group_17                     float32
# totpts_cut_group_2                      float32
# totpts_cut_group_3                      float32
# totpts_cut_group_4                      float32
# totpts_cut_group_5                      float32
# totpts_cut_group_6                      float32
# totpts_cut_group_7                      float32
# totpts_cut_group_8                      float32
# totpts_cut_group_9                      float32
# clfely_1ST DEGREE                       float32
# clfely_1ST/LIFE                         float32
# clfely_2ND DEGREE                       float32
# clfely_3RD DEGREE                       float32
# clfely_LIFE                             float32
# clfely_UNKNOWN                          float32
# dtype: object

# %%
get_config('X_train')[['age']].hist()
# Out:
# array([[<AxesSubplot:title={'center':'age'}>]], dtype=object)
